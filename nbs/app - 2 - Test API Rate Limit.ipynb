# %%
import httpx

from decouple import config

API_ACCESS_KEY = config('API_ACCESS_KEY')

headers = {
    "X-API-Key": API_ACCESS_KEY
}

endpoint = "http://127.0.0.1:8000/"
API_ACCESS_KEY
# Out:
# 'BvjjcTAkkMmxD75YUy7J8Ek30RTqi5VXegRw21nF-k0'

# %%
prompt = "a photo of TOK adult man dressed up for a pro photo shoot"
res = httpx.get(endpoint,headers=headers)
res.status_code, res.json() , res.headers.get('Retry-After')
# Out:
# (429, {'detail': 'Too Many Requests'}, '3')

# %%
import httpx

from decouple import config

API_ACCESS_KEY = config('API_ACCESS_KEY')

headers = {
    "X-API-Key": API_ACCESS_KEY
}

endpoint = "http://127.0.0.1:8000/predictions"
res = httpx.get(endpoint,headers=headers)
res.status_code, res.json() , res.headers.get('Retry-After')
# Out:
# (200,
#  [{'url': '/predictions/36v643rz6drmt0cwv3vs5fd4s8',
#    'status': 'processing',
#    'created_at': '2026-03-10T18:16:39.987000Z',
#    'completed_at': None},
#   {'url': '/predictions/t1fja6t90xrmt0cwv3jspg4fym',
#    'status': 'succeeded',
#    'created_at': '2026-03-10T17:57:11.047000Z',
#    'completed_at': '2026-03-10T17:57:26.624489Z'},
#   {'url': '/predictions/ntf516yc6srmy0cwntb8x2qtt4',
#    'status': 'succeeded',
#    'created_at': '2026-03-02T12:47:24.214000Z',
#    'completed_at': '2026-03-02T12:47:39.862199Z'},
#   {'url': '/predictions/2bq9snqpnxrmt0cwnskstnwcs4',
#    'status': 'succeeded',
#    'created_at': '2026-03-02T11:56:14.895000Z',
#    'completed_at': '2026-03-02T11:56:32.742756Z'},
#   {'url': '/predictions/0asg05tjfhrmt0cwns88w5w3wg',
#    'status': 'succeeded',
#    'created_at': '2026-03-02T11:30:25.532000Z',
#    'completed_at': '2026-03-02T11:30:43.686441Z'},
#   {'url': '/predictions/x601yskyjhrmw0cwjjxavxaqwm',
#    'status': 'succeeded',
#    'created_at': '2026-02-25T12:16:16.020000Z',
#    'completed_at': '2026-02-25T12:16:34.782031Z'},
#   {'url': '/predictions/nqrarr3vexrmy0cwjjw98yec5w',
#    'status': 'succeeded',
#    'created_at': '2026-02-25T12:14:04.151000Z',
#    'completed_at': '2026-02-25T12:14:21.136689Z'},
#   {'url': '/predictions/jb2c9mwxbhrmr0cwjjh82z8dz8',
#    'status': 'succeeded',
#    'created_at': '2026-02-25T11:50:11.036000Z',
#    'completed_at': '2026-02-25T11:50:20.849605Z'}],
#  None)

# %%
import httpx

from decouple import config

API_ACCESS_KEY = config('API_ACCESS_KEY')

headers = {
    "X-API-Key": API_ACCESS_KEY
}
params={
    "status":"processing"
}

endpoint = "http://127.0.0.1:8000/processing"
res = httpx.get(endpoint,headers=headers)
res
# Out:
# <Response [500 Internal Server Error]>

# %%
API_ACCESS_KEY = config('API_ACCESS_KEY')

headers = {
    "X-API-Key": API_ACCESS_KEY
}
endpoint = "http://127.0.0.1:8000/predictions"
preds_res = httpx.get(endpoint, headers=headers)
preds_json = preds_res.json()
preds_json
# Out:
# [{'url': '/predictions/36v643rz6drmt0cwv3vs5fd4s8',
#   'status': 'succeeded',
#   'created_at': '2026-03-10T18:16:39.987000Z',
#   'completed_at': '2026-03-10T18:16:59.362632Z'},
#  {'url': '/predictions/t1fja6t90xrmt0cwv3jspg4fym',
#   'status': 'succeeded',
#   'created_at': '2026-03-10T17:57:11.047000Z',
#   'completed_at': '2026-03-10T17:57:26.624489Z'},
#  {'url': '/predictions/ntf516yc6srmy0cwntb8x2qtt4',
#   'status': 'succeeded',
#   'created_at': '2026-03-02T12:47:24.214000Z',
#   'completed_at': '2026-03-02T12:47:39.862199Z'},
#  {'url': '/predictions/2bq9snqpnxrmt0cwnskstnwcs4',
#   'status': 'succeeded',
#   'created_at': '2026-03-02T11:56:14.895000Z',
#   'completed_at': '2026-03-02T11:56:32.742756Z'},
#  {'url': '/predictions/0asg05tjfhrmt0cwns88w5w3wg',
#   'status': 'succeeded',
#   'created_at': '2026-03-02T11:30:25.532000Z',
#   'completed_at': '2026-03-02T11:30:43.686441Z'},
#  {'url': '/predictions/x601yskyjhrmw0cwjjxavxaqwm',
#   'status': 'succeeded',
#   'created_at': '2026-02-25T12:16:16.020000Z',
#   'completed_at': '2026-02-25T12:16:34.782031Z'},
#  {'url': '/predictions/nqrarr3vexrmy0cwjjw98yec5w',
#   'status': 'succeeded',
#   'created_at': '2026-02-25T12:14:04.151000Z',
#   'completed_at': '2026-02-25T12:14:21.136689Z'},
#  {'url': '/predictions/jb2c9mwxbhrmr0cwjjh82z8dz8',
#   'status': 'succeeded',
#   'created_at': '2026-02-25T11:50:11.036000Z',
#   'completed_at': '2026-02-25T11:50:20.849605Z'}]

# %%
API_ACCESS_KEY = config('API_ACCESS_KEY')

headers = {
    "X-API-Key": API_ACCESS_KEY
}
# endpoint = "http://127.0.0.1:8000/predictions"
recent_url = preds_json[0].get('url')
print(recent_url)
if not recent_url.startswith('/'):
    recent_url = f"/{recent_url}"
detail_url = f"http://127.0.0.1:8000{recent_url}"
res = httpx.get(detail_url, headers=headers)
res.status_code 
res.json()
# Out:
# /predictions/36v643rz6drmt0cwv3vs5fd4s8
# {'id': '36v643rz6drmt0cwv3vs5fd4s8',
#  'model': 'madhusanka-slc/super-slc-v1',
#  'version': 'db2ecb62be5357f4673bdb959aea07650843f500837645d79e13965be242660b',
#  'status': 'succeeded',
#  'input': {'num_outputs': 2,
#   'output_format': 'jpg',
#   'prompt': 'a photo of TOK adult man dressed up for a traditional chinese photo shoot',
#   'replicate_weights': 'https://replicate.delivery/xezq/vH4HjBUnLDr8KhnWSLNu1DUwApBHmvdfCdHmm0BFAHtfEJLWA/trained_model.tar'},
#  'output': ['https://replicate.delivery/xezq/BvaNuh4icmJqJRGe2wXoVeJvNNtgS91ivFJ2r5UXAi3bIhPWA/out-0.jpg',
#   'https://replicate.delivery/xezq/gdbBA1VlrSJWOJOze9x1090aRS4zEDbGL6hKKB13zqfbIhPWA/out-1.jpg'],
#  'logs': 'free=21341639004160\nDownloading weights\n2026-03-10T18:16:42Z | INFO  | [ Initiating ] chunk_size=150M dest=/tmp/tmp8j_at_o0/weights url=https://replicate.delivery/xezq/vH4HjBUnLDr8KhnWSLNu1DUwApBHmvdfCdHmm0BFAHtfEJLWA/trained_model.tar\n2026-03-10T18:16:42Z | INFO  | [ Cache Service ] enabled=true scheme=http target=hermes.services.svc.cluster.local\n2026-03-10T18:16:42Z | INFO  | [ Cache URL Rewrite ] enabled=true target_url=http://hermes.services.svc.cluster.local/replicate.delivery/xezq/vH4HjBUnLDr8KhnWSLNu1DUwApBHmvdfCdHmm0BFAHtfEJLWA/trained_model.tar url=https://replicate.delivery/xezq/vH4HjBUnLDr8KhnWSLNu1DUwApBHmvdfCdHmm0BFAHtfEJLWA/trained_model.tar\n2026-03-10T18:16:43Z | INFO  | [ Redirect ] redirect_url=http://r8-east4-loras-ric2.cwlota.com/6bc5aff68c4d90b992d679e57d679902d22ef347d4133c6a4684d0c1d7355304?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Checksum-Mode=ENABLED&X-Amz-Credential=CWVOGIYODJJPRECK%2F20260310%2FUS-EAST-04A%2Fs3%2Faws4_request&X-Amz-Date=20260310T181642Z&X-Amz-Expires=600&X-Amz-SignedHeaders=host&x-id=GetObject&X-Amz-Signature=f05ecd4fd58b6e4a266a6c80fd7ea98f2bab05255f3e79ec9657ce4bd1239863 url=http://hermes.services.svc.cluster.local/replicate.delivery/xezq/vH4HjBUnLDr8KhnWSLNu1DUwApBHmvdfCdHmm0BFAHtfEJLWA/trained_model.tar\n2026-03-10T18:16:43Z | INFO  | [ Complete ] dest=/tmp/tmp8j_at_o0/weights size="172 MB" total_elapsed=0.298s url=https://replicate.delivery/xezq/vH4HjBUnLDr8KhnWSLNu1DUwApBHmvdfCdHmm0BFAHtfEJLWA/trained_model.tar\nDownloaded weights in 0.36s\nLoaded LoRAs in 0.88s\nUsing seed: 40775\nPrompt: a photo of TOK adult man dressed up for a traditional chinese photo shoot\n[!] txt2img mode\n  0%|          | 0/28 [00:00<?, ?it/s]\n  4%|▎         | 1/28 [00:00<00:13,  1.99it/s]\n  7%|▋         | 2/28 [00:00<00:11,  2.25it/s]\n 11%|█         | 3/28 [00:01<00:11,  2.13it/s]\n 14%|█▍        | 4/28 [00:01<00:11,  2.07it/s]\n 18%|█▊        | 5/28 [00:02<00:11,  2.04it/s]\n 21%|██▏       | 6/28 [00:02<00:10,  2.02it/s]\n 25%|██▌       | 7/28 [00:03<00:10,  2.01it/s]\n 29%|██▊       | 8/28 [00:03<00:09,  2.01it/s]\n 32%|███▏      | 9/28 [00:04<00:09,  2.00it/s]\n 36%|███▌      | 10/28 [00:04<00:09,  2.00it/s]\n 39%|███▉      | 11/28 [00:05<00:08,  2.00it/s]\n 43%|████▎     | 12/28 [00:05<00:08,  1.99it/s]\n 46%|████▋     | 13/28 [00:06<00:07,  1.99it/s]\n 50%|█████     | 14/28 [00:06<00:07,  1.99it/s]\n 54%|█████▎    | 15/28 [00:07<00:06,  1.99it/s]\n 57%|█████▋    | 16/28 [00:07<00:06,  1.99it/s]\n 61%|██████    | 17/28 [00:08<00:05,  1.99it/s]\n 64%|██████▍   | 18/28 [00:08<00:05,  1.99it/s]\n 68%|██████▊   | 19/28 [00:09<00:04,  1.99it/s]\n 71%|███████▏  | 20/28 [00:09<00:04,  1.99it/s]\n 75%|███████▌  | 21/28 [00:10<00:03,  1.99it/s]\n 79%|███████▊  | 22/28 [00:10<00:03,  1.99it/s]\n 82%|████████▏ | 23/28 [00:11<00:02,  1.99it/s]\n 86%|████████▌ | 24/28 [00:11<00:02,  1.99it/s]\n 89%|████████▉ | 25/28 [00:12<00:01,  1.99it/s]\n 93%|█████████▎| 26/28 [00:12<00:01,  1.99it/s]\n 96%|█████████▋| 27/28 [00:13<00:00,  1.99it/s]\n100%|██████████| 28/28 [00:13<00:00,  1.99it/s]\n100%|██████████| 28/28 [00:13<00:00,  2.01it/s]\nTotal safe images: 2 out of 2\n',
#  'error': None,
#  'metrics': {'predict_time': 16.473233779, 'total_time': 19.375632809},
#  'created_at': '2026-03-10T18:16:39.987Z',
#  'started_at': '2026-03-10T18:16:42.889399031Z',
#  'completed_at': '2026-03-10T18:16:59.362632809Z',
#  'urls': {'cancel': 'https://api.replicate.com/v1/predictions/36v643rz6drmt0cwv3vs5fd4s8/cancel',
#   'get': 'https://api.replicate.com/v1/predictions/36v643rz6drmt0cwv3vs5fd4s8',
#   'stream': 'https://stream.replicate.com/v1/files/jbxs-hwry2wizgm2loeas7piji3butqao7rdrelhvoxpokx32hsygxz6q',
#   'web': 'https://replicate.com/p/36v643rz6drmt0cwv3vs5fd4s8'}}

# %%
import pathlib

for obj in preds_json:
    path = obj.get('url')
    endpoint = f"http://127.0.0.1:8000{path}"
    res = httpx.get(endpoint, headers=headers)
    if res.status_code not in range(200, 299):
        continue
    data = res.json()
    print(data)


    # _id = data.get('id')
    # _input = data.get('input') or {}
    # num_outputs = _input.get('num_outputs') or 0
    # _output = data.get('output')
    # if _output is None:
    #     continue
    # print(data)
    # output_names = [pathlib.Path(x) for x in _output]
    # print(num_outputs, output_names)
    # for x, output_path in enumerate(output_names):
    #     suffix = output_path.suffix
    #     print(f"{path}/file/{x}{suffix}")
    # print(_id, num_outputs, _output)
    # break
# Out:
# {'id': '36v643rz6drmt0cwv3vs5fd4s8', 'url': '/predictions/36v643rz6drmt0cwv3vs5fd4s8', 'model': 'madhusanka-slc/super-slc-v1', 'version': 'db2ecb62be5357f4673bdb959aea07650843f500837645d79e13965be242660b', 'status': 'succeeded', 'created_at': '2026-03-10T18:16:39.987000Z', 'completed_at': '2026-03-10T18:16:59.362632Z', 'files': ['/predictions/36v643rz6drmt0cwv3vs5fd4s8/files/0.jpg', '/predictions/36v643rz6drmt0cwv3vs5fd4s8/files/1.jpg'], 'num_outputs': 2}
# {'id': 't1fja6t90xrmt0cwv3jspg4fym', 'url': '/predictions/t1fja6t90xrmt0cwv3jspg4fym', 'model': 'madhusanka-slc/super-slc-v1', 'version': 'db2ecb62be5357f4673bdb959aea07650843f500837645d79e13965be242660b', 'status': 'succeeded', 'created_at': '2026-03-10T17:57:11.047000Z', 'completed_at': '2026-03-10T17:57:26.624489Z', 'files': ['/predictions/t1fja6t90xrmt0cwv3jspg4fym/files/0.jpg', '/predictions/t1fja6t90xrmt0cwv3jspg4fym/files/1.jpg'], 'num_outputs': 2}
# {'id': 'ntf516yc6srmy0cwntb8x2qtt4', 'url': '/predictions/ntf516yc6srmy0cwntb8x2qtt4', 'model': 'madhusanka-slc/super-slc-v1', 'version': 'db2ecb62be5357f4673bdb959aea07650843f500837645d79e13965be242660b', 'status': 'succeeded', 'created_at': '2026-03-02T12:47:24.214000Z', 'completed_at': '2026-03-02T12:47:39.862199Z', 'files': [], 'num_outputs': 0}
# {'id': '2bq9snqpnxrmt0cwnskstnwcs4', 'url': '/predictions/2bq9snqpnxrmt0cwnskstnwcs4', 'model': 'madhusanka-slc/super-slc-v1', 'version': 'db2ecb62be5357f4673bdb959aea07650843f500837645d79e13965be242660b', 'status': 'succeeded', 'created_at': '2026-03-02T11:56:14.895000Z', 'completed_at': '2026-03-02T11:56:32.742756Z', 'files': [], 'num_outputs': 0}
# {'id': '0asg05tjfhrmt0cwns88w5w3wg', 'url': '/predictions/0asg05tjfhrmt0cwns88w5w3wg', 'model': 'madhusanka-slc/super-slc-v1', 'version': 'db2ecb62be5357f4673bdb959aea07650843f500837645d79e13965be242660b', 'status': 'succeeded', 'created_at': '2026-03-02T11:30:25.532000Z', 'completed_at': '2026-03-02T11:30:43.686441Z', 'files': [], 'num_outputs': 0}
# {'id': 'x601yskyjhrmw0cwjjxavxaqwm', 'url': '/predictions/x601yskyjhrmw0cwjjxavxaqwm', 'model': 'madhusanka-slc/super-slc-v1', 'version': 'db2ecb62be5357f4673bdb959aea07650843f500837645d79e13965be242660b', 'status': 'succeeded', 'created_at': '2026-02-25T12:16:16.020000Z', 'completed_at': '2026-02-25T12:16:34.782031Z', 'files': [], 'num_outputs': 0}
# {'id': 'nqrarr3vexrmy0cwjjw98yec5w', 'url': '/predictions/nqrarr3vexrmy0cwjjw98yec5w', 'model': 'madhusanka-slc/super-slc-v1', 'version': 'db2ecb62be5357f4673bdb959aea07650843f500837645d79e13965be242660b', 'status': 'succeeded', 'created_at': '2026-02-25T12:14:04.151000Z', 'completed_at': '2026-02-25T12:14:21.136689Z', 'files': [], 'num_outputs': 0}
# {'id': 'jb2c9mwxbhrmr0cwjjh82z8dz8', 'url': '/predictions/jb2c9mwxbhrmr0cwjjh82z8dz8', 'model': 'madhusanka-slc/super-slc-v1', 'version': 'db2ecb62be5357f4673bdb959aea07650843f500837645d79e13965be242660b', 'status': 'succeeded', 'created_at': '2026-02-25T11:50:11.036000Z', 'completed_at': '2026-02-25T11:50:20.849605Z', 'files': ['/predictions/jb2c9mwxbhrmr0cwjjh82z8dz8/files/0.webp'], 'num_outputs': 1}
